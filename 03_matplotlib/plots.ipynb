# %% [markdown]
# Python Matplotlib examples

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

# %%
X = np.linspace(-np.pi, np.pi, 15)
C = np.cos(X)
S = np.sin(X)

# %%
plt.plot(X, C)
plt.show()
