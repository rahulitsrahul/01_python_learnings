# %%
import albumentations as A
import numpy as np
from PIL import Image, ImageDraw
from matplotlib import pyplot as plt
import os

# %%
def get_transform():
    angle_upper_limit = 45
    angle_lower_limit = 45
    transform = A.Compose([
        A.HorizontalFlip(p=1),
        A.Rotate(limit=(angle_upper_limit, angle_lower_limit), p=1),
        A.Resize(width=100, height=150),
    ], bbox_params=A.BboxParams(format='pascal_voc', label_fields=['category_ids']))
    return transform

# %%
if __name__=="__main__":
    img_path = r'im_1.jpg'
    im = Image.open(img_path)
    img = im.resize((250, 150))
    image = np.array(img)
    
    bbox = [140, 15, 200, 50] # format xmin, ymin, xmax, ymax
    draw = ImageDraw.Draw(img)
    draw.rectangle(bbox, fill=None)
    display(img)
    
    transform = get_transform()
    transformed = transform(image=image, bboxes=[bbox], category_ids=[0])
    img_transformed = transformed['image']
    bbox_transformed = transformed['bboxes']
    bbox_transformed = np.array(bbox_transformed).astype(np.int64).tolist()
    
    im_t = Image.fromarray(img_transformed)
    draw = ImageDraw.Draw(im_t)
    
    for i in range(len(bbox_transformed)):
        draw.rectangle(bbox_transformed[i], fill=None)
    display(im_t)
# Out:
# <PIL.Image.Image image mode=RGB size=250x150>
# <PIL.Image.Image image mode=RGB size=100x150>

# %%
im_t.size
bbox_transformed
#transformed['bboxes']
# Out:
# [[14, 20, 41, 69]]
